# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv("data/train.csv")
data = data.drop(columns=["Cabin"])
data = data.dropna(axis=0)
data.describe(include="all")
y = data.Survived
features = ["Pclass","Sex","Age","SibSp","Parch","Ticket","Fare","Embarked"]
X = pd.get_dummies(data[features])

X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=1)
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
# just trying a simple linear one first

clf = svm.SVC(kernel="linear")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_val)

print(accuracy_score(y_val, y_pred))
# Out:
# 0.8089887640449438

# %%
# hyperparameter optimization
# This block uses the Kfold thing for accuracy ratings (and the grid search), which is why 
# it's a little better/different than the next block

# C_val = [10**exp for exp in range(-5,6)]
C = [10**exp for exp in range(-5,6)]
kernels = ["linear","poly","rbf","sigmoid"]
degrees = [num for num in range(2,5)]
model = svm.SVC()

grid = dict(kernel=kernels,degree=degrees,C=C)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X, y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.820240 using {'C': 10000, 'degree': 2, 'kernel': 'poly'}
# 0.632069 (0.038520) with: {'C': 1e-05, 'degree': 2, 'kernel': 'linear'}
# 0.595509 (0.002725) with: {'C': 1e-05, 'degree': 2, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 1e-05, 'degree': 2, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 1e-05, 'degree': 2, 'kernel': 'sigmoid'}
# 0.632069 (0.038520) with: {'C': 1e-05, 'degree': 3, 'kernel': 'linear'}
# 0.599724 (0.003704) with: {'C': 1e-05, 'degree': 3, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 1e-05, 'degree': 3, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 1e-05, 'degree': 3, 'kernel': 'sigmoid'}
# 0.632069 (0.038520) with: {'C': 1e-05, 'degree': 4, 'kernel': 'linear'}
# 0.602531 (0.011198) with: {'C': 1e-05, 'degree': 4, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 1e-05, 'degree': 4, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 1e-05, 'degree': 4, 'kernel': 'sigmoid'}
# 0.653098 (0.048905) with: {'C': 0.0001, 'degree': 2, 'kernel': 'linear'}
# 0.599724 (0.003704) with: {'C': 0.0001, 'degree': 2, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.0001, 'degree': 2, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.0001, 'degree': 2, 'kernel': 'sigmoid'}
# 0.653098 (0.048905) with: {'C': 0.0001, 'degree': 3, 'kernel': 'linear'}
# 0.602531 (0.011198) with: {'C': 0.0001, 'degree': 3, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.0001, 'degree': 3, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.0001, 'degree': 3, 'kernel': 'sigmoid'}
# 0.653098 (0.048905) with: {'C': 0.0001, 'degree': 4, 'kernel': 'linear'}
# 0.606737 (0.017797) with: {'C': 0.0001, 'degree': 4, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.0001, 'degree': 4, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.0001, 'degree': 4, 'kernel': 'sigmoid'}
# 0.667153 (0.051956) with: {'C': 0.001, 'degree': 2, 'kernel': 'linear'}
# 0.605338 (0.016163) with: {'C': 0.001, 'degree': 2, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.001, 'degree': 2, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.001, 'degree': 2, 'kernel': 'sigmoid'}
# 0.667153 (0.051956) with: {'C': 0.001, 'degree': 3, 'kernel': 'linear'}
# 0.609554 (0.019543) with: {'C': 0.001, 'degree': 3, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.001, 'degree': 3, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.001, 'degree': 3, 'kernel': 'sigmoid'}
# 0.667153 (0.051956) with: {'C': 0.001, 'degree': 4, 'kernel': 'linear'}
# 0.608145 (0.019006) with: {'C': 0.001, 'degree': 4, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.001, 'degree': 4, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.001, 'degree': 4, 'kernel': 'sigmoid'}
# 0.773840 (0.040422) with: {'C': 0.01, 'degree': 2, 'kernel': 'linear'}
# 0.616567 (0.023431) with: {'C': 0.01, 'degree': 2, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.01, 'degree': 2, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.01, 'degree': 2, 'kernel': 'sigmoid'}
# 0.773840 (0.040422) with: {'C': 0.01, 'degree': 3, 'kernel': 'linear'}
# 0.612361 (0.022345) with: {'C': 0.01, 'degree': 3, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.01, 'degree': 3, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.01, 'degree': 3, 'kernel': 'sigmoid'}
# 0.773840 (0.040422) with: {'C': 0.01, 'degree': 4, 'kernel': 'linear'}
# 0.613759 (0.020393) with: {'C': 0.01, 'degree': 4, 'kernel': 'poly'}
# 0.595509 (0.002725) with: {'C': 0.01, 'degree': 4, 'kernel': 'rbf'}
# 0.595509 (0.002725) with: {'C': 0.01, 'degree': 4, 'kernel': 'sigmoid'}
# 0.779435 (0.029748) with: {'C': 0.1, 'degree': 2, 'kernel': 'linear'}
# 0.624998 (0.028929) with: {'C': 0.1, 'degree': 2, 'kernel': 'poly'}
# 0.662986 (0.072806) with: {'C': 0.1, 'degree': 2, 'kernel': 'rbf'}
# 0.612410 (0.043488) with: {'C': 0.1, 'degree': 2, 'kernel': 'sigmoid'}
# 0.779435 (0.029748) with: {'C': 0.1, 'degree': 3, 'kernel': 'linear'}
# 0.626396 (0.027195) with: {'C': 0.1, 'degree': 3, 'kernel': 'poly'}
# 0.662986 (0.072806) with: {'C': 0.1, 'degree': 3, 'kernel': 'rbf'}
# 0.612410 (0.043488) with: {'C': 0.1, 'degree': 3, 'kernel': 'sigmoid'}
# 0.779435 (0.029748) with: {'C': 0.1, 'degree': 4, 'kernel': 'linear'}
# 0.615168 (0.019006) with: {'C': 0.1, 'degree': 4, 'kernel': 'poly'}
# 0.662986 (0.072806) with: {'C': 0.1, 'degree': 4, 'kernel': 'rbf'}
# 0.612410 (0.043488) with: {'C': 0.1, 'degree': 4, 'kernel': 'sigmoid'}
# 0.807604 (0.020845) with: {'C': 1, 'degree': 2, 'kernel': 'linear'}
# 0.643307 (0.044585) with: {'C': 1, 'degree': 2, 'kernel': 'poly'}
# 0.670029 (0.073251) with: {'C': 1, 'degree': 2, 'kernel': 'rbf'}
# 0.568916 (0.042243) with: {'C': 1, 'degree': 2, 'kernel': 'sigmoid'}
# 0.807604 (0.020845) with: {'C': 1, 'degree': 3, 'kernel': 'linear'}
# 0.636245 (0.030332) with: {'C': 1, 'degree': 3, 'kernel': 'poly'}
# 0.670029 (0.073251) with: {'C': 1, 'degree': 3, 'kernel': 'rbf'}
# 0.568916 (0.042243) with: {'C': 1, 'degree': 3, 'kernel': 'sigmoid'}
# 0.807604 (0.020845) with: {'C': 1, 'degree': 4, 'kernel': 'linear'}
# 0.633438 (0.025795) with: {'C': 1, 'degree': 4, 'kernel': 'poly'}
# 0.670029 (0.073251) with: {'C': 1, 'degree': 4, 'kernel': 'rbf'}
# 0.568916 (0.042243) with: {'C': 1, 'degree': 4, 'kernel': 'sigmoid'}
# 0.804797 (0.014031) with: {'C': 10, 'degree': 2, 'kernel': 'linear'}
# 0.664346 (0.050383) with: {'C': 10, 'degree': 2, 'kernel': 'poly'}
# 0.719196 (0.061861) with: {'C': 10, 'degree': 2, 'kernel': 'rbf'}
# 0.566148 (0.055732) with: {'C': 10, 'degree': 2, 'kernel': 'sigmoid'}
# 0.804797 (0.014031) with: {'C': 10, 'degree': 3, 'kernel': 'linear'}
# 0.661460 (0.040183) with: {'C': 10, 'degree': 3, 'kernel': 'poly'}
# 0.719196 (0.061861) with: {'C': 10, 'degree': 3, 'kernel': 'rbf'}
# 0.566148 (0.055732) with: {'C': 10, 'degree': 3, 'kernel': 'sigmoid'}
# 0.804797 (0.014031) with: {'C': 10, 'degree': 4, 'kernel': 'linear'}
# 0.657274 (0.037143) with: {'C': 10, 'degree': 4, 'kernel': 'poly'}
# 0.719196 (0.061861) with: {'C': 10, 'degree': 4, 'kernel': 'rbf'}
# 0.566148 (0.055732) with: {'C': 10, 'degree': 4, 'kernel': 'sigmoid'}
# 0.801980 (0.013395) with: {'C': 100, 'degree': 2, 'kernel': 'linear'}
# 0.745799 (0.042229) with: {'C': 100, 'degree': 2, 'kernel': 'poly'}
# 0.771053 (0.045902) with: {'C': 100, 'degree': 2, 'kernel': 'rbf'}
# 0.567547 (0.051582) with: {'C': 100, 'degree': 2, 'kernel': 'sigmoid'}
# 0.801980 (0.013395) with: {'C': 100, 'degree': 3, 'kernel': 'linear'}
# 0.688181 (0.035748) with: {'C': 100, 'degree': 3, 'kernel': 'poly'}
# 0.771053 (0.045902) with: {'C': 100, 'degree': 3, 'kernel': 'rbf'}
# 0.567547 (0.051582) with: {'C': 100, 'degree': 3, 'kernel': 'sigmoid'}
# 0.801980 (0.013395) with: {'C': 100, 'degree': 4, 'kernel': 'linear'}
# 0.683985 (0.038871) with: {'C': 100, 'degree': 4, 'kernel': 'poly'}
# 0.771053 (0.045902) with: {'C': 100, 'degree': 4, 'kernel': 'rbf'}
# 0.567547 (0.051582) with: {'C': 100, 'degree': 4, 'kernel': 'sigmoid'}
# 0.810401 (0.004049) with: {'C': 1000, 'degree': 2, 'kernel': 'linear'}
# 0.817394 (0.038609) with: {'C': 1000, 'degree': 2, 'kernel': 'poly'}
# 0.796375 (0.046493) with: {'C': 1000, 'degree': 2, 'kernel': 'rbf'}
# 0.568945 (0.050284) with: {'C': 1000, 'degree': 2, 'kernel': 'sigmoid'}
# 0.810401 (0.004049) with: {'C': 1000, 'degree': 3, 'kernel': 'linear'}
# 0.743022 (0.039448) with: {'C': 1000, 'degree': 3, 'kernel': 'poly'}
# 0.796375 (0.046493) with: {'C': 1000, 'degree': 3, 'kernel': 'rbf'}
# 0.568945 (0.050284) with: {'C': 1000, 'degree': 3, 'kernel': 'sigmoid'}
# 0.810401 (0.004049) with: {'C': 1000, 'degree': 4, 'kernel': 'linear'}
# 0.707889 (0.037243) with: {'C': 1000, 'degree': 4, 'kernel': 'poly'}
# 0.796375 (0.046493) with: {'C': 1000, 'degree': 4, 'kernel': 'rbf'}
# 0.568945 (0.050284) with: {'C': 1000, 'degree': 4, 'kernel': 'sigmoid'}
# 0.779543 (0.018570) with: {'C': 10000, 'degree': 2, 'kernel': 'linear'}
# 0.820240 (0.028952) with: {'C': 10000, 'degree': 2, 'kernel': 'poly'}
# 0.796366 (0.036289) with: {'C': 10000, 'degree': 2, 'kernel': 'rbf'}
# 0.568945 (0.050284) with: {'C': 10000, 'degree': 2, 'kernel': 'sigmoid'}
# 0.779543 (0.018570) with: {'C': 10000, 'degree': 3, 'kernel': 'linear'}
# 0.781020 (0.049064) with: {'C': 10000, 'degree': 3, 'kernel': 'poly'}
# 0.796366 (0.036289) with: {'C': 10000, 'degree': 3, 'kernel': 'rbf'}
# 0.568945 (0.050284) with: {'C': 10000, 'degree': 3, 'kernel': 'sigmoid'}
# 0.779543 (0.018570) with: {'C': 10000, 'degree': 4, 'kernel': 'linear'}
# 0.726219 (0.052243) with: {'C': 10000, 'degree': 4, 'kernel': 'poly'}
# 0.796366 (0.036289) with: {'C': 10000, 'degree': 4, 'kernel': 'rbf'}
# 0.568945 (0.050284) with: {'C': 10000, 'degree': 4, 'kernel': 'sigmoid'}
# 0.779533 (0.018126) with: {'C': 100000, 'degree': 2, 'kernel': 'linear'}
# 0.816054 (0.029703) with: {'C': 100000, 'degree': 2, 'kernel': 'poly'}
# 0.778085 (0.038893) with: {'C': 100000, 'degree': 2, 'kernel': 'rbf'}
# 0.567547 (0.051582) with: {'C': 100000, 'degree': 2, 'kernel': 'sigmoid'}
# 0.779533 (0.018126) with: {'C': 100000, 'degree': 3, 'kernel': 'linear'}
# 0.788023 (0.037981) with: {'C': 100000, 'degree': 3, 'kernel': 'poly'}
# 0.778085 (0.038893) with: {'C': 100000, 'degree': 3, 'kernel': 'rbf'}
# 0.567547 (0.051582) with: {'C': 100000, 'degree': 3, 'kernel': 'sigmoid'}
# 0.779533 (0.018126) with: {'C': 100000, 'degree': 4, 'kernel': 'linear'}
# 0.740284 (0.046274) with: {'C': 100000, 'degree': 4, 'kernel': 'poly'}
# 0.778085 (0.038893) with: {'C': 100000, 'degree': 4, 'kernel': 'rbf'}
# 0.567547 (0.051582) with: {'C': 100000, 'degree': 4, 'kernel': 'sigmoid'}

# %%
# no Kfold; and me just brute forcing it with nested loops lol

def get_accuracy(C_val, kernel, degree, X_train, X_val, y_train, y_val):
    model = svm.SVC(C=C_val, kernel=kernel, degree=degree)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    return accuracy_score(y_val, y_pred)

accuracies = []  
    
for c_val in C:
    for kernel in kernels:
        for degree in degrees:
            accuracy = get_accuracy(c_val, kernel, degree, X_train, X_val, y_train, y_val)
            accuracies.append({"C": c_val,"kernel": kernel,"deg":degree, "accuracy":accuracy})

bestAccuracy = max(accuracies, key=lambda x:x["accuracy"])

print(*sorted(accuracies, key = lambda x:x["accuracy"], reverse = True), sep = "\n")
# Out:
# {'C': 100000, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.8258426966292135}
# {'C': 1, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.8089887640449438}
# {'C': 1, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.8089887640449438}
# {'C': 1, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.8089887640449438}
# {'C': 10, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.8089887640449438}
# {'C': 10, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.8089887640449438}
# {'C': 10, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.8089887640449438}
# {'C': 10000, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.8089887640449438}
# {'C': 10000, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.8089887640449438}
# {'C': 10000, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.8089887640449438}
# {'C': 10000, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.8089887640449438}
# {'C': 100000, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.8033707865168539}
# {'C': 1000, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.797752808988764}
# {'C': 1000, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.797752808988764}
# {'C': 1000, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.797752808988764}
# {'C': 100000, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.797752808988764}
# {'C': 100000, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.797752808988764}
# {'C': 100000, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.797752808988764}
# {'C': 0.1, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.7865168539325843}
# {'C': 0.1, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.7865168539325843}
# {'C': 0.1, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.7865168539325843}
# {'C': 1000, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.7865168539325843}
# {'C': 0.01, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.7808988764044944}
# {'C': 0.01, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.7808988764044944}
# {'C': 0.01, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.7808988764044944}
# {'C': 10000, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.7752808988764045}
# {'C': 10000, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.7752808988764045}
# {'C': 10000, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.7752808988764045}
# {'C': 100, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.7696629213483146}
# {'C': 100, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.7696629213483146}
# {'C': 100, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.7696629213483146}
# {'C': 100, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.7696629213483146}
# {'C': 100, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.7696629213483146}
# {'C': 100, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.7696629213483146}
# {'C': 1000, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.7696629213483146}
# {'C': 1000, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.7696629213483146}
# {'C': 1000, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.7696629213483146}
# {'C': 100000, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.7696629213483146}
# {'C': 100000, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.7696629213483146}
# {'C': 100000, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.7696629213483146}
# {'C': 10000, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.7528089887640449}
# {'C': 100000, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.7471910112359551}
# {'C': 10000, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.7359550561797753}
# {'C': 100, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.7191011235955056}
# {'C': 1000, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.702247191011236}
# {'C': 10, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.6853932584269663}
# {'C': 10, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.6853932584269663}
# {'C': 10, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.6853932584269663}
# {'C': 1000, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.6797752808988764}
# {'C': 1, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.6573033707865169}
# {'C': 1, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.6573033707865169}
# {'C': 1, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.6573033707865169}
# {'C': 100, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.6573033707865169}
# {'C': 0.1, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.6460674157303371}
# {'C': 0.1, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.6460674157303371}
# {'C': 0.1, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.6460674157303371}
# {'C': 10, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.6460674157303371}
# {'C': 100, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.6460674157303371}
# {'C': 0.0001, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.6404494382022472}
# {'C': 0.0001, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.6404494382022472}
# {'C': 0.0001, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.6404494382022472}
# {'C': 0.001, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.6404494382022472}
# {'C': 0.001, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.6404494382022472}
# {'C': 0.001, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.6404494382022472}
# {'C': 10, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.6292134831460674}
# {'C': 10, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.6235955056179775}
# {'C': 1, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.6123595505617978}
# {'C': 1e-05, 'kernel': 'linear', 'deg': 2, 'accuracy': 0.6067415730337079}
# {'C': 1e-05, 'kernel': 'linear', 'deg': 3, 'accuracy': 0.6067415730337079}
# {'C': 1e-05, 'kernel': 'linear', 'deg': 4, 'accuracy': 0.6067415730337079}
# {'C': 1, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.6067415730337079}
# {'C': 0.01, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.601123595505618}
# {'C': 0.1, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.601123595505618}
# {'C': 1, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.601123595505618}
# {'C': 0.01, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.5955056179775281}
# {'C': 0.1, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.5955056179775281}
# {'C': 0.0001, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.5898876404494382}
# {'C': 0.001, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.5898876404494382}
# {'C': 0.001, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.5898876404494382}
# {'C': 0.001, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.5898876404494382}
# {'C': 0.01, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.5898876404494382}
# {'C': 0.1, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.5898876404494382}
# {'C': 0.1, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5898876404494382}
# {'C': 0.1, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5898876404494382}
# {'C': 0.1, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5898876404494382}
# {'C': 1, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5842696629213483}
# {'C': 1, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5842696629213483}
# {'C': 1, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5842696629213483}
# {'C': 100, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5842696629213483}
# {'C': 100, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5842696629213483}
# {'C': 100, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5842696629213483}
# {'C': 1000, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5842696629213483}
# {'C': 1000, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5842696629213483}
# {'C': 1000, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5842696629213483}
# {'C': 10000, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5842696629213483}
# {'C': 10000, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5842696629213483}
# {'C': 10000, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5842696629213483}
# {'C': 100000, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5842696629213483}
# {'C': 100000, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5842696629213483}
# {'C': 100000, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5842696629213483}
# {'C': 1e-05, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.5786516853932584}
# {'C': 1e-05, 'kernel': 'poly', 'deg': 4, 'accuracy': 0.5786516853932584}
# {'C': 0.0001, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.5786516853932584}
# {'C': 0.0001, 'kernel': 'poly', 'deg': 3, 'accuracy': 0.5786516853932584}
# {'C': 10, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5786516853932584}
# {'C': 10, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5786516853932584}
# {'C': 10, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5786516853932584}
# {'C': 1e-05, 'kernel': 'poly', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 1e-05, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 1e-05, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 1e-05, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.5730337078651685}
# {'C': 1e-05, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 1e-05, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 1e-05, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5730337078651685}
# {'C': 0.0001, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 0.0001, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 0.0001, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.5730337078651685}
# {'C': 0.0001, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 0.0001, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 0.0001, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5730337078651685}
# {'C': 0.001, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 0.001, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 0.001, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.5730337078651685}
# {'C': 0.001, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 0.001, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 0.001, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5730337078651685}
# {'C': 0.01, 'kernel': 'rbf', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 0.01, 'kernel': 'rbf', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 0.01, 'kernel': 'rbf', 'deg': 4, 'accuracy': 0.5730337078651685}
# {'C': 0.01, 'kernel': 'sigmoid', 'deg': 2, 'accuracy': 0.5730337078651685}
# {'C': 0.01, 'kernel': 'sigmoid', 'deg': 3, 'accuracy': 0.5730337078651685}
# {'C': 0.01, 'kernel': 'sigmoid', 'deg': 4, 'accuracy': 0.5730337078651685}
